# %%
vocabularies = {"intelligate":"zinnmonn","accountant":"kaikeisi"}


input_word = input("Any help? Expand your vocabulary:")
         # there is a word in vocabulary or not.
new_or = input_word in vocabularies.keys()

if new_or == True: # alredy learned
   print("Again?  the meaning is "+vocabularies[input_word])
elif new_or == False: # new words
    print("new word! wait a sec...")
    from selenium import webdriver

    browser = webdriver.Safari()
    browser.get('https://ejje.weblio.jp/')
    elem = browser.find_element_by_id('searchWord')
    elem.send_keys(input_word)
    btn = browser.find_element_by_xpath('//*[@id="headFixBxTR"]/input')
    btn.click()
    meaning = browser.find_element_by_xpath('//*[@id="summary"]/div[2]/table/tbody/tr/td[2]')
    new_word = meaning.text
    print(new_word)
#vocabularies[input_word]=new_word
# Out:
# Any help? Expand your vocabulary:good
# new word! wait a sec...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-411ff0ce57c6> in <module>
#      12     from selenium import webdriver
#      13
# ---> 14     browser = webdriver.Safari()
#      15     browser.get('https://ejje.weblio.jp/')
#      16     elem = browser.find_element_by_id('searchWord')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/safari/webdriver.py in __init__(self, port, executable_path, reuse_service, desired_capabilities, quiet, keep_alive, service_args)
#      63             self,
#      64             command_executor=executor,
# ---> 65             desired_capabilities=desired_capabilities)
#      66
#      67         self._is_remote = False
#
# ...
